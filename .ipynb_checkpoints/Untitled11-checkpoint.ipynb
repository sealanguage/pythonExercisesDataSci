# %%
#  this is a string   

s = input("Input a string: ")

line = s.split(" ")
s = "-".join(line)

print("LINE ", line)
print(s)
# Out:
# Input a string: this is a string
# LINE  ['this', 'is', 'a', 'string']
# this-is-a-string

# %%
def split_and_join(line):
    # write your code here
    s = " "
    line = s.split(" ")
    s = "-".join(line)
    return s

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(s)
    print(result)
# Out:
# this is a string
# this-is-a-string
# -

# %%
grades = []
sum = 0

while True :
    print( "Enter your choices - " )
    print( "Enter grades -> 1" )
    print( "List grades -> 2" )
    print( "Delete a grade -> 3" )
    print( "Update a grade -> 4" )
    print( "Clear grades -> 5" )
    
    print( "Exit program -> 6" )
    
    choice = int(input( "->" ))
    
        
#     if not (len(choice) == 1 and choice.isnumeric()) :
#         print( "Enter a valid choice number 1 - 6" )
#         break
    
    if int(choice == 6) :
        break
    
    if int(choice == 1) :
        print( "enter a grades. 'e' to exit." )
        
        while ( True ) :
            grade = input( "->" )
            if grade == "e" :
                break
            else :
                grade = float(grade)
                grades.append(grade)

            continue
        
    if int(choice == 2) :
        for grade in grades :
            print( grade )
            
    if int(choice == 3 ) :
        for grade in grades :
            print(grades)
        index = int(input( "Enter the index to delete" ))
        if index < len(grades) - 1 and index >= 0 :
            grades.pop(index)
        else :
            print( "Invalid index. Try again." )
            
    if int(choice == 4 ) :
        for grade in grades :
            print(grades)
        index = int(input( "enter grade to update" ))
        if index < len(grades) - 1 and index >= 0 :
            new_grade = float(input( "->" ))
            grades[index] = new_grade
        else :
            print( "Invalid index. Try again" )
            
    if int(choice == 5 ) :
        
            
            
#     if(len(choice == 1)) :
#         print( "Enter 'e' to exit" )
# Out:
# Enter your choices -
# Enter grades -> 1
# List grades -> 2
# Delete a grade -> 3
# Update a grade -> 4
# Exit program -> 6
# ->1
# enter a grades. 'e' to exit.
# ->1.2
# ->2.3
# ->3.4
# ->4.1
# ->e
# Enter your choices -
# Enter grades -> 1
# List grades -> 2
# Delete a grade -> 3
# Update a grade -> 4
# Exit program -> 6
# ->2
# 1.2
# 2.3
# 3.4
# 4.1
# Enter your choices -
# Enter grades -> 1
# List grades -> 2
# Delete a grade -> 3
# Update a grade -> 4
# Exit program -> 6
# ->4
# [1.2, 2.3, 3.4, 4.1]
# [1.2, 2.3, 3.4, 4.1]
# [1.2, 2.3, 3.4, 4.1]
# [1.2, 2.3, 3.4, 4.1]
# enter grade to update1
# ->2
# Enter your choices -
# Enter grades -> 1
# List grades -> 2
# Delete a grade -> 3
# Update a grade -> 4
# Exit program -> 6
# ->2
# 1.2
# 2.0
# 3.4
# 4.1
# Enter your choices -
# Enter grades -> 1
# List grades -> 2
# Delete a grade -> 3
# Update a grade -> 4
# Exit program -> 6
# ->1
# enter a grades. 'e' to exit.
# ->1.2
# ->2.3
# ->3.4
# ->4.1
# ->e
# Enter your choices -
# Enter grades -> 1
# List grades -> 2
# Delete a grade -> 3
# Update a grade -> 4
# Exit program -> 6
# ->2
# 1.2
# 2.0
# 3.4
# 4.1
# 1.2
# 2.3
# 3.4
# 4.1
# Enter your choices -
# Enter grades -> 1
# List grades -> 2
# Delete a grade -> 3
# Update a grade -> 4
# Exit program -> 6
# ->4
# [1.2, 2.0, 3.4, 4.1, 1.2, 2.3, 3.4, 4.1]
# [1.2, 2.0, 3.4, 4.1, 1.2, 2.3, 3.4, 4.1]
# [1.2, 2.0, 3.4, 4.1, 1.2, 2.3, 3.4, 4.1]
# [1.2, 2.0, 3.4, 4.1, 1.2, 2.3, 3.4, 4.1]
# [1.2, 2.0, 3.4, 4.1, 1.2, 2.3, 3.4, 4.1]
# [1.2, 2.0, 3.4, 4.1, 1.2, 2.3, 3.4, 4.1]
# [1.2, 2.0, 3.4, 4.1, 1.2, 2.3, 3.4, 4.1]
# [1.2, 2.0, 3.4, 4.1, 1.2, 2.3, 3.4, 4.1]
# enter grade to update3
# ->6.6
# Enter your choices -
# Enter grades -> 1
# List grades -> 2
# Delete a grade -> 3
# Update a grade -> 4
# Exit program -> 6
# ->2
# 1.2
# 2.0
# 3.4
# 6.6
# 1.2
# 2.3
# 3.4
# 4.1
# Enter your choices -
# Enter grades -> 1
# List grades -> 2
# Delete a grade -> 3
# Update a grade -> 4
# Exit program -> 6

# %% [markdown]
# ###

# %%
grades = []

while True :
    print( "Enter your choice -> ")
    print( "Exit program 6 -> ")
    
    choice = input(" -> ")
    
    if int(choice) == 6 :
        break
# Out:
# Enter your choice ->
# Exit program 6 ->
#  -> 6
